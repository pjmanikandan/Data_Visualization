# %%
import pandas as pd

# %%
dataset=pd.read_csv("Preprocessing_placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
plac=dataset[dataset["status"]=="Placed"]

# %%
dataset.shape
# Out:
# (215, 15)

# %%
dataset.shape[0]
# Out:
# 215

# %%
import seaborn as sb

# %%
import matplotlib.pyplot as plt

# %%
sb.distplot(dataset["ssc_p"],hist=True,kde=True,kde_kws={"color":"Green"})
# Out:
# C:\Users\PJ MANI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ssc_p', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis

# %%
sb.jointplot(x="ssc_p",y="salary",data=plac)
plt.show()

# %%
sb.jointplot(x="ssc_p",y="salary",data=plac,kind='hex')
plt.show()

# %%
sb.jointplot(x="ssc_p",y="salary",data=plac,kind='kde')
plt.show()

# %%
#Pairplot

# %%
sb.pairplot(dataset,hue="gender",diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %% [markdown]
# # Categorical Plot

# %%
sb.stripplot(x='ssc_b',y='ssc_p',data=dataset)
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.stripplot(x='gender',y='ssc_p',data=dataset,jitter=True)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='ssc_p'>

# %%
sb.swarmplot(x='gender',y='ssc_p',data=dataset)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='ssc_p'>

# %% [markdown]
# # Distribution Observation

# %%
sb.violinplot(x='gender',y='ssc_p',data=plac)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='ssc_p'>

# %%
sb.violinplot(x='ssc_b',y='ssc_p',data=plac,hue='gender')
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.violinplot(x='specialisation',y='salary',data=plac)
# Out:
# <AxesSubplot:xlabel='specialisation', ylabel='salary'>

# %%
sb.violinplot(x='specialisation',y='salary',data=plac,hue='gender')
# Out:
# <AxesSubplot:xlabel='specialisation', ylabel='salary'>

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=plac)
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=plac,hue='gender')
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.barplot(x='ssc_b',y='ssc_p',data=plac,hue='gender')
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.pointplot(x='ssc_b',y='ssc_p',data=plac,hue='gender')
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.pointplot(x='ssc_b',y='ssc_p',data=plac)
# Out:
# <AxesSubplot:xlabel='ssc_b', ylabel='ssc_p'>

# %%
sb.boxplot(data=plac,orient='h')
# Out:
# <AxesSubplot:>

# %%
#factorplot
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset("exercise")
sb.factorplot(x="time",y="pulse",hue="kind",kind="violin",col="diet",data=df);
plt.show()
# Out:
# C:\Users\PJ MANI\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#factorplot
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset("tips")
sb.regplot(x="total_bill",y="tip",data=df)
sb.lmplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
#factorplot
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset("anscombe")
#sb.regplot(x="total_bill",y="tip",data=df)
sb.lmplot(x="x",y="y",data=df.query("dataset=='II'"))
plt.show()

# %%
#factorplot
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset("anscombe")
#sb.regplot(x="total_bill",y="tip",data=df)
sb.lmplot(x="x",y="y",data=df.query("dataset=='II'"),order=2)
plt.show()

# %%
#factorplot
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset("tips")
#sb.regplot(x="total_bill",y="tip",data=df)
g=sb.FacetGrid(df,col="time")
g.map(plt.hist,"tip")
plt.show()

# %%
#factorplot
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset("iris")
g=sb.PairGrid(df)
g.map(plt.scatter)
plt.show()
